# %% [markdown]
# # How to
#
# Check out this guide
#
# https://github.com/rd11490/NBA_Tutorials/blob/master/shot_bins/binning_shots.py
#
# change the season in url, takes awhile to load and might lag, save .json file
#
# https://stats.nba.com/stats/shotchartdetail?PlayerID=0&TeamID=0&GameID=&LeagueID=00&Season=2005-06&SeasonType=Regular+Season&Outcome=&Location=&Month=0&SeasonSegment=&DateFrom=&DateTo=&OpponentTeamID=0&VsConference=&VsDivision=&PlayerPosition=&GameSegment=&Period=0&LastNGames=0&AheadBehind=&ContextMeasure=FGM&ClutchTime=&RookieYear=

# %%
import pandas as pd
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt  

cwd = 'G:\\NBA'
#cwd = os.getcwd()

# %%
def loadPcl(cwd, sub, fname, mode='rb'):
    if sub == "":
        with open(os.path.join(cwd,fname ), mode) as f: 
            df = pickle.load(f)
    else:
        with open(os.path.join(cwd,sub,fname ), mode) as f: 
            df = pickle.load(f)
    return df
def writeDF(df,cwd, sub, fname):
    if sub == "":
        dir = os.path.join( cwd,fname)

    else:
        dir = os.path.join( cwd,sub,fname)

    df.to_pickle(dir)
    print("wrote " + fname)

# %%
reg0506 = loadPcl(cwd,"shotData","shotsReg0506.pkl")
reg1819 = loadPcl(cwd,"shotData","shotsReg1819.pkl")
reg1718 = loadPcl(cwd,"shotData","shotsReg1718.pkl")
reg1617 = loadPcl(cwd,"shotData","shotsReg1617.pkl")

comb = reg1617.append(reg1718).append(reg1819)

df =reg1819

# %%
def agg_shots(group):
    total_shots = group['FGA'].sum() # Calculate the number of attempted shots
    made_shots = group["FGM"].sum() # Calculate the number of made shots
    percentage = round(made_shots/total_shots, 3) # Calculate the field goal percentage (round to 3 decimal places)
    
    shotpts = group["SHOT_PTS"].sum() # 0 for miss, 2 for 2pt, 3 for 3pt
    pps = round(shotpts/total_shots, 3)

    return pd.Series([made_shots, total_shots, percentage, pps])

# %%
def makeTable(df,grpByCol):
    agg = df.groupby(grpByCol).apply(agg_shots).reset_index()
    
#     if isinstance(grpByCol, list):
#         agg.columns = grpByCol + [ "FGM", "FGA", "FG%","PPS"]
#     else:
#         agg.columns = [grpByCol, "FGM", "FGA", "FG%","PPS"]
    agg.columns = (grpByCol + [ "FGM", "FGA", "FG%","PPS"])
    agg = agg.sort_values("FGA",ascending=False)
    
    return agg

# %%
def makeTables(df):
    n_shots = df.FGA.sum()
    
    aggType = makeTable(df,["SHOT_TYPE"])
    aggZone = makeTable(df,["SHOT_ZONE"])
    aggSvSt = makeTable(df,["SHOT_VALUE","SHOT_TYPE"])
    aggZT = makeTable(df,["SHOT_ZONE","SHOT_TYPE"])
    
    aggPVT = makeTable(df,["PLAYER_NAME","SHOT_VALUE","SHOT_TYPE"])
    aggPZ = makeTable(df,["PLAYER_NAME","SHOT_ZONE"])
    aggPZT = makeTable(df,["PLAYER_NAME","SHOT_ZONE","SHOT_TYPE"])
    aggPV = makeTable(df,["PLAYER_NAME","SHOT_VALUE"])
    aggPVZT = makeTable(df,["PLAYER_NAME","SHOT_VALUE","SHOT_ZONE","SHOT_TYPE"])
    
    df2= df[df.SHOT_TYPE.isin(['Turnaround Jump Shot',"Fadeaway Jump Shot","Turnaround Fadeaway shot","Turnaround Fadeaway Bank Jump Shot"])]
    aggTF = makeTable(df2,["PLAYER_NAME","SHOT_ZONE"])


    return aggType,aggZone, aggSvSt,aggZT,aggPVT, aggPZ, aggPZT, aggPV,aggPVZT,aggTF

# %%
cols = ["Jump Shot","Pullup Jump shot","Step Back Jump shot",
        'Turnaround Jump Shot',"Fadeaway Jump Shot","Turnaround Fadeaway shot","Turnaround Fadeaway Bank Jump Shot"]#'Running Jump Shot', 'Running Pull-Up Jump Shot',

# %%
# league 1819
aggType,aggZone, aggSvSt,aggZT,aggPVT, aggPZ, aggPZT, aggPV,aggPVZT,aggTF = makeTables(reg1819)



# 0506
aggType06,aggZone06, aggSvSt06,aggZT06,aggPVT06, aggPZ06, aggPZT06, aggPV06, aggPVZT06,aggTF06 = makeTables(reg0506)
# Out:
# c:\program files\python37\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
aggTypeC,aggZoneC, aggSvStC,aggZTC,aggPVTC, aggPZC, aggPZTC, aggPVC,aggPVZTC,aggTFC = makeTables(comb)
# Out:
# c:\program files\python37\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
aggType18,aggZone18, aggSvSt18,aggZT18,aggPVT18, aggPZ18, aggPZT18, aggPV18,aggPVZT18,aggTF18 = makeTables(reg1718)

# %% [markdown]
# # Turnarounds and fadeaways
# Comparing 05/06 vs 18/19

# %%
aggZT[(aggZT.SHOT_ZONE=="MR")].head(10)
# Out:
#    SHOT_ZONE                        SHOT_TYPE     FGM      FGA    FG%    PPS
# 52        MR                 Pullup Jump shot  5076.0  11791.0  0.430  0.861
# 50        MR                        Jump Shot  3754.0  10363.0  0.362  0.729
# 60        MR              Step Back Jump shot  1504.0   3489.0  0.431  0.862
# 44        MR               Fadeaway Jump Shot   749.0   1916.0  0.391  0.782
# 64        MR         Turnaround Fadeaway shot   581.0   1374.0  0.423  0.846
# 66        MR             Turnaround Jump Shot   469.0   1261.0  0.372  0.744
# 39        MR       Driving Floating Jump Shot   322.0    845.0  0.381  0.762
# 46        MR               Floating Jump shot   249.0    637.0  0.391  0.782
# 38        MR  Driving Floating Bank Jump Shot   165.0    335.0  0.493  0.985
# 49        MR                   Jump Bank Shot   109.0    248.0  0.440  0.879

# %%
aggZone
# Out:
#   SHOT_ZONE      FGM      FGA    FG%    PPS
# 5        RA  45574.0  72427.0  0.629  1.258
# 0      ATB3  21061.0  60285.0  0.349  1.048
# 4     PAINT  14177.0  35122.0  0.404  0.807
# 3        MR  13404.0  33275.0  0.403  0.807
# 2       LC3   3519.0   9112.0  0.386  1.159
# 6       RC3   3313.0   8771.0  0.378  1.133
# 1    BCOURT     14.0    466.0  0.030  0.090

# %%
tf = aggTF[(aggTF.SHOT_ZONE =="MR") ]

# %%
mr = aggPZ[(aggPZ.SHOT_ZONE =="MR")  ]

# %%
js = aggPZT[(aggPZT.SHOT_ZONE =="MR") & (aggPZT.SHOT_TYPE == "Jump Shot")  ]

# %%
mrg = pd.merge(tf, js, left_on = ["PLAYER_NAME"], right_on=["PLAYER_NAME"], how ="left", suffixes=('', '_JS'))
mrg["FG%_DIFF"] = mrg["FG%"] - mrg["FG%_JS"]

mrg[["PLAYER_NAME","FGM","FGA","FG%","FG%_JS","FG%_DIFF","FGM_JS","FGA_JS"]].head(10)#.sort_values("FG%_DIFF",ascending=False)#.head(15)
#mrg.head()
# Out:
#          PLAYER_NAME   FGM    FGA    FG%  FG%_JS  FG%_DIFF  FGM_JS  FGA_JS
# 0  LaMarcus Aldridge  99.0  216.0  0.458   0.473    -0.015   114.0   241.0
# 1       Kevin Durant  89.0  153.0  0.582   0.432     0.150    54.0   125.0
# 2      DeMar DeRozan  45.0  121.0  0.372   0.451    -0.079    51.0   113.0
# 3        Dwyane Wade  37.0  112.0  0.330   0.167     0.163     5.0    30.0
# 4      Klay Thompson  49.0   96.0  0.510   0.325     0.185    49.0   151.0
# 5       Lou Williams  36.0   88.0  0.409   0.280     0.129    14.0    50.0
# 6       Kyrie Irving  47.0   86.0  0.547   0.480     0.067    24.0    50.0
# 7       LeBron James  30.0   78.0  0.385   0.541    -0.156    20.0    37.0
# 8      Kawhi Leonard  31.0   70.0  0.443   0.475    -0.032    28.0    59.0
# 9       Jayson Tatum  24.0   68.0  0.353   0.188     0.165     6.0    32.0

# %% [markdown]
# # 05/06

# %%
aggZT06[(aggZT06.SHOT_ZONE=="MR")].head(10)
# Out:
#    SHOT_ZONE             SHOT_TYPE      FGM      FGA    FG%    PPS
# 19        MR             Jump Shot  22608.0  59859.0  0.378  0.756
# 26        MR  Turnaround Jump Shot   1355.0   2487.0  0.545  1.090
# 14        MR    Fadeaway Jump Shot   1196.0   2009.0  0.595  1.191
# 22        MR     Running Jump Shot    535.0    934.0  0.573  1.146
# 17        MR        Jump Bank Shot    611.0    910.0  0.671  1.343
# 16        MR             Hook Shot    146.0    401.0  0.364  0.728
# 18        MR        Jump Hook Shot     85.0    163.0  0.521  1.043
# 25        MR  Turnaround Hook Shot     65.0    116.0  0.560  1.121
# 21        MR     Running Hook Shot     15.0     27.0  0.556  1.111
# 15        MR        Hook Bank Shot      6.0      7.0  0.857  1.714

# %%
aggZone06
# Out:
#   SHOT_ZONE      FGM      FGA    FG%    PPS
# 3        MR  26627.0  66926.0  0.398  0.796
# 5        RA  37304.0  63017.0  0.592  1.184
# 0      ATB3   9752.0  27816.0  0.351  1.052
# 4     PAINT  10167.0  25107.0  0.405  0.810
# 2       LC3   2184.0   5668.0  0.385  1.156
# 6       RC3   2123.0   5409.0  0.392  1.176
# 1    BCOURT      9.0    371.0  0.024  0.073

# %%
tf = aggTF06[(aggTF06.SHOT_ZONE =="MR") ]#.head(10)

mr = aggPZ06[(aggPZ06.SHOT_ZONE =="MR")  ]#.head(10)

js = aggPZT06[(aggPZT06.SHOT_ZONE =="MR") & (aggPZT06.SHOT_TYPE == "Jump Shot")  ]#.head(10)

mrg = pd.merge(tf, js, left_on = ["PLAYER_NAME"], right_on=["PLAYER_NAME"], how ="left", suffixes=('', '_JS'))
mrg["FG%_DIFF"] = mrg["FG%"] - mrg["FG%_JS"]
#mrg.sort_values("FG%_DIFF",ascending=False)#.head(15)
mrg[["PLAYER_NAME","FGM","FGA","FG%","FG%_JS","FG%_DIFF","FGM_JS","FGA_JS"]].head(15)#.sort_values("FG%_DIFF",ascending=False)#.head(15)
#mrg.head()
# Out:
#          PLAYER_NAME    FGM    FGA    FG%  FG%_JS  FG%_DIFF  FGM_JS  FGA_JS
# 0      Dirk Nowitzki  101.0  164.0  0.616   0.439     0.177   260.0   592.0
# 1        Kobe Bryant  106.0  153.0  0.693   0.355     0.338   281.0   792.0
# 2      Kevin Garnett   72.0  131.0  0.550   0.451     0.099   215.0   477.0
# 3   Jason Richardson   58.0  112.0  0.518   0.296     0.222    80.0   270.0
# 4           Yao Ming   54.0  100.0  0.540   0.252     0.288    41.0   163.0
# 5       LeBron James   44.0   93.0  0.473   0.348     0.125   178.0   511.0
# 6    Carmelo Anthony   38.0   73.0  0.521   0.398     0.123   225.0   566.0
# 7        Elton Brand   53.0   73.0  0.726   0.417     0.309   221.0   530.0
# 8        Dwyane Wade   29.0   70.0  0.414   0.359     0.055   163.0   454.0
# 9         Chris Bosh   24.0   63.0  0.381   0.455    -0.074   212.0   466.0
# 10   Rasheed Wallace   36.0   61.0  0.590   0.387     0.203   111.0   287.0
# 11       Paul Pierce   39.0   61.0  0.639   0.411     0.228   182.0   443.0
# 12  Jerry Stackhouse   28.0   59.0  0.475   0.376     0.099    79.0   210.0
# 13      Vince Carter   29.0   59.0  0.492   0.386     0.106   139.0   360.0
# 14     Allen Iverson   45.0   54.0  0.833   0.351     0.482   235.0   669.0

# %% [markdown]
# # 3P Shot Types

# %%
mrg3p = pd.merge(aggPVTC, aggPVC[["PLAYER_NAME","SHOT_VALUE","FGA","FG%"]], left_on = ["PLAYER_NAME","SHOT_VALUE"], right_on=["PLAYER_NAME","SHOT_VALUE"], how ="left", suffixes=('', '_3P'))
mrg3p["FG%_DIFF"] = mrg3p["FG%"] - mrg3p["FG%_3P"]
#mrg.head()

# %%
p3 = mrg3p[(mrg3p.SHOT_VALUE==3) & ((mrg3p.SHOT_TYPE=="Step Back Jump shot") | (mrg3p.SHOT_TYPE=="Pullup Jump shot"))& (mrg3p.FGA>70) ].sort_values("FG%_DIFF",ascending=False) #& (aggPS.FGA>30)& (aggPS["FG%"]>0.42)
p3[["PLAYER_NAME","SHOT_VALUE","SHOT_TYPE","FGM","FGA","FG%","FG%_3P","FG%_DIFF","FGA_3P"]].head(20)
# Out:
#             PLAYER_NAME  SHOT_VALUE            SHOT_TYPE    FGM    FGA    FG%  \
# 1843     Andre Iguodala           3     Pullup Jump shot   48.0   75.0  0.640
# 1264     Draymond Green           3     Pullup Jump shot   60.0  106.0  0.566
# 1776         Quinn Cook           3     Pullup Jump shot   50.0   78.0  0.641
# 523       Klay Thompson           3     Pullup Jump shot  153.0  242.0  0.632
# 332       Stephen Curry           3     Pullup Jump shot  212.0  341.0  0.622
# 820       Stephen Curry           3  Step Back Jump shot   96.0  159.0  0.604
# 1696      Austin Rivers           3     Pullup Jump shot   41.0   82.0  0.500
# 1593    Wesley Matthews           3  Step Back Jump shot   44.0   87.0  0.506
# 503        Kevin Durant           3     Pullup Jump shot  127.0  250.0  0.508
# 807        Lou Williams           3     Pullup Jump shot   78.0  162.0  0.481
# 762       Isaiah Thomas           3     Pullup Jump shot   78.0  171.0  0.456
# 1784      Tobias Harris           3     Pullup Jump shot   38.0   78.0  0.487
# 1077       LeBron James           3  Step Back Jump shot   56.0  123.0  0.455
# 1803  Spencer Dinwiddie           3  Step Back Jump shot   33.0   77.0  0.429
# 1507       Yogi Ferrell           3     Pullup Jump shot   43.0   92.0  0.467
# 1312        Paul George           3  Step Back Jump shot   49.0  103.0  0.476
# 588         Patty Mills           3     Pullup Jump shot  105.0  222.0  0.473
# 1369         J.J. Barea           3     Pullup Jump shot   43.0  100.0  0.430
# 1164    Jordan Clarkson           3     Pullup Jump shot   47.0  115.0  0.409
# 1111        Zach LaVine           3     Pullup Jump shot   54.0  120.0  0.450
#
#       FG%_3P  FG%_DIFF  FGA_3P
# 1843   0.331     0.309   438.0
# 1264   0.300     0.266   684.0
# 1776   0.418     0.223   330.0
# 523    0.418     0.214  1766.0
# 332    0.424     0.198  2099.0
# 820    0.424     0.180  2099.0
# 1696   0.357     0.143   984.0
# 1593   0.371     0.135  1284.0
# 503    0.384     0.124  1113.0
# 807    0.362     0.119  1254.0
# 762    0.356     0.100   877.0
# 1784   0.389     0.098  1151.0
# 1077   0.358     0.097  1074.0
# 1803   0.335     0.094   904.0
# 1507   0.374     0.093   684.0
# 1312   0.392     0.084  1859.0
# 588    0.392     0.081  1173.0
# 1369   0.350     0.080   589.0
# 1164   0.332     0.077  1116.0
# 1111   0.374     0.076   754.0

# %%
tf = aggTFC[(aggTFC.SHOT_ZONE =="MR") &(aggTFC.FGA > 50)]#.head(10)

mr = aggPZC[(aggPZC.SHOT_ZONE =="MR")  ]#.head(10)

js = aggPZTC[(aggPZTC.SHOT_ZONE =="MR") & (aggPZTC.SHOT_TYPE == "Jump Shot")  ]#.head(10)

mrg = pd.merge(tf, js, left_on = ["PLAYER_NAME"], right_on=["PLAYER_NAME"], how ="left", suffixes=('', '_JS'))
mrg["FG%_DIFF"] = mrg["FG%"] - mrg["FG%_JS"]
#mrg.sort_values("FG%_DIFF",ascending=False)#.head(15)
mrg[["PLAYER_NAME","FGM","FGA","FG%","FG%_JS","FG%_DIFF","FGM_JS","FGA_JS"]]#.sort_values("FG%_DIFF",ascending=False)#.head(15)
#mrg.head()
# Out:
#                 PLAYER_NAME    FGM    FGA    FG%  FG%_JS  FG%_DIFF  FGM_JS  \
# 0         LaMarcus Aldridge  263.0  599.0  0.439   0.426     0.013   362.0
# 1             DeMar DeRozan  152.0  364.0  0.418   0.344     0.074   162.0
# 2               Dwyane Wade  112.0  288.0  0.389   0.249     0.140    69.0
# 3              Kevin Durant  158.0  280.0  0.564   0.403     0.161   160.0
# 4              LeBron James  113.0  273.0  0.414   0.367     0.047    87.0
# 5            Andrew Wiggins  104.0  267.0  0.390   0.271     0.119   107.0
# 6             Dirk Nowitzki   92.0  223.0  0.413   0.454    -0.041   248.0
# 7                Marc Gasol   96.0  221.0  0.434   0.434     0.000   247.0
# 8             Klay Thompson  111.0  206.0  0.539   0.380     0.159   217.0
# 9           Harrison Barnes   90.0  200.0  0.450   0.366     0.084   164.0
# 10             Jimmy Butler   82.0  190.0  0.432   0.282     0.150   107.0
# 11            Anthony Davis   81.0  178.0  0.455   0.360     0.095   261.0
# 12          Khris Middleton   90.0  177.0  0.508   0.388     0.120   125.0
# 13             Lou Williams   79.0  177.0  0.446   0.294     0.152    55.0
# 14       Kristaps Porzingis   76.0  172.0  0.442   0.364     0.078   117.0
# 15             Kyrie Irving   85.0  167.0  0.509   0.411     0.098   106.0
# 16       Karl-Anthony Towns   65.0  164.0  0.396   0.439    -0.043   150.0
# 17          Carmelo Anthony   73.0  163.0  0.448   0.403     0.045   261.0
# 18            Marcus Morris   61.0  154.0  0.396   0.374     0.022   123.0
# 19        Russell Westbrook   62.0  149.0  0.416   0.237     0.179    78.0
# 20              Evan Turner   74.0  146.0  0.507   0.279     0.228    29.0
# 21           Nikola Vucevic   58.0  144.0  0.403   0.438    -0.035   311.0
# 22            Kawhi Leonard   68.0  143.0  0.476   0.420     0.056   113.0
# 23             Devin Booker   61.0  137.0  0.445   0.319     0.126   105.0
# 24         Shaun Livingston   66.0  136.0  0.485   0.276     0.209    34.0
# 25            Nicolas Batum   54.0  126.0  0.429   0.358     0.071   121.0
# 26              Joel Embiid   44.0  122.0  0.361   0.398    -0.037   131.0
# 27              Serge Ibaka   53.0  119.0  0.445   0.479    -0.034   245.0
# 28           Damian Lillard   57.0  118.0  0.483   0.371     0.112    62.0
# 29             Aaron Gordon   45.0  115.0  0.391   0.273     0.118    54.0
# ..                      ...    ...    ...    ...     ...       ...     ...
# 45            Tobias Harris   37.0   86.0  0.430   0.388     0.042   113.0
# 46          Jordan Clarkson   39.0   83.0  0.470   0.333     0.137    61.0
# 47               Jeff Green   41.0   81.0  0.506   0.266     0.240    38.0
# 48          Michael Beasley   28.0   80.0  0.350   0.388    -0.038    80.0
# 49          Otto Porter Jr.   40.0   79.0  0.506   0.377     0.129   116.0
# 50  Rondae Hollis-Jefferson   27.0   77.0  0.351   0.360    -0.009    54.0
# 51             Jamal Murray   26.0   75.0  0.347   0.333     0.014    47.0
# 52              Zach LaVine   26.0   74.0  0.351   0.224     0.127    35.0
# 53        Jonas Valanciunas   32.0   74.0  0.432   0.447    -0.015    85.0
# 54             Bradley Beal   33.0   74.0  0.446   0.336     0.110   112.0
# 55               Kyle Lowry   29.0   70.0  0.414   0.246     0.168    15.0
# 56           Gordon Hayward   22.0   69.0  0.319   0.318     0.001    62.0
# 57          Emmanuel Mudiay   29.0   68.0  0.426   0.311     0.115    37.0
# 58          Marco Belinelli   27.0   66.0  0.409   0.409     0.000   123.0
# 59                John Wall   31.0   66.0  0.470   0.154     0.316    40.0
# 60          Lauri Markkanen   16.0   63.0  0.254   0.391    -0.137    43.0
# 61             Vince Carter   28.0   63.0  0.444   0.340     0.104    17.0
# 62              Joe Johnson   27.0   63.0  0.429   0.242     0.187    22.0
# 63             Goran Dragic   25.0   62.0  0.403   0.266     0.137    54.0
# 64         DeMarcus Cousins   24.0   62.0  0.387   0.327     0.060    82.0
# 65             Jaylen Brown   29.0   61.0  0.475   0.369     0.106    24.0
# 66             Nikola Jokic   26.0   60.0  0.433   0.466    -0.033   173.0
# 67         D'Angelo Russell   21.0   56.0  0.375   0.318     0.057    42.0
# 68             Myles Turner   30.0   56.0  0.536   0.424     0.112   291.0
# 69              Ben Simmons   11.0   56.0  0.196   0.111     0.085     4.0
# 70               J.J. Barea   28.0   55.0  0.509   0.329     0.180    26.0
# 71              Rodney Hood   23.0   55.0  0.418   0.361     0.057    65.0
# 72            Deandre Ayton   25.0   53.0  0.472   0.344     0.128    55.0
# 73               Kevin Love   19.0   53.0  0.358   0.346     0.012    62.0
# 74           Frank Kaminsky   20.0   52.0  0.385   0.297     0.088    30.0
#
#     FGA_JS
# 0    849.0
# 1    471.0
# 2    277.0
# 3    397.0
# 4    237.0
# 5    395.0
# 6    546.0
# 7    569.0
# 8    571.0
# 9    448.0
# 10   380.0
# 11   726.0
# 12   322.0
# 13   187.0
# 14   321.0
# 15   258.0
# 16   342.0
# 17   647.0
# 18   329.0
# 19   329.0
# 20   104.0
# 21   710.0
# 22   269.0
# 23   329.0
# 24   123.0
# 25   338.0
# 26   329.0
# 27   511.0
# 28   167.0
# 29   198.0
# ..     ...
# 45   291.0
# 46   183.0
# 47   143.0
# 48   206.0
# 49   308.0
# 50   150.0
# 51   141.0
# 52   156.0
# 53   190.0
# 54   333.0
# 55    61.0
# 56   195.0
# 57   119.0
# 58   301.0
# 59   260.0
# 60   110.0
# 61    50.0
# 62    91.0
# 63   203.0
# 64   251.0
# 65    65.0
# 66   371.0
# 67   132.0
# 68   687.0
# 69    36.0
# 70    79.0
# 71   180.0
# 72   160.0
# 73   179.0
# 74   101.0
#
# [75 rows x 8 columns]
